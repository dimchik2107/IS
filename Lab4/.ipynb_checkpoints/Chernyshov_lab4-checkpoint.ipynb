# %% [markdown]
# # Лабораторная работа № 4
#
# Распознавание рукописных символов
#
# Выполнил:
#     Студент группы БФИ1901
#     Чернышов Дмитрий
#
# Задачи:
#
#    1. Ознакомиться с представлением графических данных
#    2. Ознакомиться с простейшим способом передачи графических данных нейронной сети
#    3. Создать модель
#    4. Настроить параметры обучения
#    5. Написать функцию, позволяющая загружать изображение пользователи и классифицировать его

# %% [markdown]
# # Цель работы:
# Реализовать классификацию черно-белых изображений рукописных цифр (28x28) по 10
# категориям (от 0 до 9). Набор данных содержит 60,000 изображений для обучения и 10,000 изображений для
# тестирования.

# %%
import tensorflow as tf
mnist = tf.keras.datasets.mnist
(train_images, train_labels),(test_images, test_labels) = mnist.load_data()

import matplotlib.pyplot as plt
plt.imshow(train_images[0],cmap=plt.cm.binary)
plt.show()
print(train_labels[0])

train_images = train_images / 255.0
test_images = test_images / 255.0

from tensorflow.keras.utils import to_categorical
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

from tensorflow.keras.layers import Dense, Activation, Flatten
from tensorflow.keras.models import Sequential
model = Sequential()
model.add(Flatten()) #Flatten используется для конвертации входящих данных в меньшую размерность.
model.add(Dense(256, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(train_images, train_labels, epochs=5, batch_size=128)

test_loss, test_acc = model.evaluate(test_images, test_labels)
print('test_acc:', test_acc)
print('test_loss:', test_loss)
# Out:
# 5
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3079 - accuracy: 0.9145
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1351 - accuracy: 0.9610
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0936 - accuracy: 0.9726
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0694 - accuracy: 0.9795
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0537 - accuracy: 0.9844
# 313/313 [==============================] - 0s 996us/step - loss: 0.0741 - accuracy: 0.9770
# test_acc: 0.9769999980926514
# test_loss: 0.07411479204893112

# %%
import tensorflow as tf
mnist = tf.keras.datasets.mnist
(train_images, train_labels),(test_images, test_labels) = mnist.load_data()

import matplotlib.pyplot as plt
plt.imshow(train_images[0],cmap=plt.cm.binary)
plt.show()
print(train_labels[0])

train_images = train_images / 255.0
test_images = test_images / 255.0

from tensorflow.keras.utils import to_categorical
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

from tensorflow.keras.layers import Dense, Activation, Flatten
from tensorflow.keras.models import Sequential
model = Sequential()
model.add(Flatten())
model.add(Dense(30, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(train_images, train_labels, epochs=5, batch_size=128)

test_loss, test_acc = model.evaluate(test_images, test_labels)
print('test_acc:', test_acc)
print('test_loss:', test_loss)
# Out:
# 5
# Epoch 1/5
# 469/469 [==============================] - 1s 1ms/step - loss: 0.5143 - accuracy: 0.8588
# Epoch 2/5
# 469/469 [==============================] - 0s 1ms/step - loss: 0.2579 - accuracy: 0.9276
# Epoch 3/5
# 469/469 [==============================] - 0s 1ms/step - loss: 0.2166 - accuracy: 0.9395
# Epoch 4/5
# 469/469 [==============================] - 0s 1ms/step - loss: 0.1907 - accuracy: 0.9456
# Epoch 5/5
# 469/469 [==============================] - 0s 1ms/step - loss: 0.1711 - accuracy: 0.9510
# 313/313 [==============================] - 0s 793us/step - loss: 0.1702 - accuracy: 0.9520
# test_acc: 0.9520000219345093
# test_loss: 0.17024767398834229

# %%
import tensorflow as tf
mnist = tf.keras.datasets.mnist
(train_images, train_labels),(test_images, test_labels) = mnist.load_data()

import matplotlib.pyplot as plt
plt.imshow(train_images[0],cmap=plt.cm.binary)
plt.show()
print(train_labels[0])

train_images = train_images / 255.0
test_images = test_images / 255.0

from tensorflow.keras.utils import to_categorical
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

from tensorflow.keras.layers import Dense, Activation, Flatten
from tensorflow.keras.models import Sequential
model = Sequential()
model.add(Flatten())
model.add(Dense(30, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='SGD',loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(train_images, train_labels, epochs=5, batch_size=128)

test_loss, test_acc = model.evaluate(test_images, test_labels)
print('test_acc:', test_acc)
print('test_loss:', test_loss)
# Out:
# 5
# Epoch 1/5
# 469/469 [==============================] - 1s 1ms/step - loss: 1.3747 - accuracy: 0.6326
# Epoch 2/5
# 469/469 [==============================] - 0s 1ms/step - loss: 0.6523 - accuracy: 0.8288
# Epoch 3/5
# 469/469 [==============================] - 0s 965us/step - loss: 0.5010 - accuracy: 0.8643
# Epoch 4/5
# 469/469 [==============================] - 1s 1ms/step - loss: 0.4327 - accuracy: 0.8818
# Epoch 5/5
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3934 - accuracy: 0.8910
# 313/313 [==============================] - 0s 1ms/step - loss: 0.3598 - accuracy: 0.9005
# test_acc: 0.9004999995231628
# test_loss: 0.3598458468914032

# %%
import tensorflow as tf
mnist = tf.keras.datasets.mnist
(train_images, train_labels),(test_images, test_labels) = mnist.load_data()

import matplotlib.pyplot as plt
plt.imshow(train_images[0],cmap=plt.cm.binary)
plt.show()
print(train_labels[0])

train_images = train_images / 255.0
test_images = test_images / 255.0

from tensorflow.keras.utils import to_categorical
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

from tensorflow.keras.layers import Dense, Activation, Flatten
from tensorflow.keras.models import Sequential
model = Sequential()
model.add(Flatten())
model.add(Dense(30, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='RMSprop',loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(train_images, train_labels, epochs=5, batch_size=128)

test_loss, test_acc = model.evaluate(test_images, test_labels)
print('test_acc:', test_acc)
print('test_loss:', test_loss)
# Out:
# 5
# Epoch 1/5
# 469/469 [==============================] - 1s 1ms/step - loss: 0.4773 - accuracy: 0.8729
# Epoch 2/5
# 469/469 [==============================] - 1s 1ms/step - loss: 0.2629 - accuracy: 0.9248
# Epoch 3/5
# 469/469 [==============================] - 1s 1ms/step - loss: 0.2211 - accuracy: 0.9370
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1932 - accuracy: 0.9451
# Epoch 5/5
# 469/469 [==============================] - 1s 1ms/step - loss: 0.1723 - accuracy: 0.9506
# 313/313 [==============================] - 0s 926us/step - loss: 0.1732 - accuracy: 0.9485
# test_acc: 0.9484999775886536
# test_loss: 0.17322586476802826

# %%
import tensorflow as tf
mnist = tf.keras.datasets.mnist
(train_images, train_labels),(test_images, test_labels) = mnist.load_data()

import matplotlib.pyplot as plt
plt.imshow(train_images[0],cmap=plt.cm.binary)
plt.show()
print(train_labels[0])

train_images = train_images / 255.0
test_images = test_images / 255.0

from tensorflow.keras.utils import to_categorical
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

from tensorflow.keras.layers import Dense, Activation, Flatten
from tensorflow.keras.models import Sequential
model = Sequential()
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(10, activation='softmax'))

x = tf.keras.optimizers.Adam(learning_rate=0.0005) #learning_rate - скорость обучения
model.compile(optimizer=x,loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(train_images, train_labels, epochs=5, batch_size=128)

test_loss, test_acc = model.evaluate(test_images, test_labels)
print('test_acc:', test_acc)
print('test_loss:', test_loss)
# Out:
# 5
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3938 - accuracy: 0.8943
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1821 - accuracy: 0.9495
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1337 - accuracy: 0.9620
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1051 - accuracy: 0.9706
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0847 - accuracy: 0.9763
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0901 - accuracy: 0.9726
# test_acc: 0.972599983215332
# test_loss: 0.09011979401111603

# %%
import numpy as np
from PIL import Image
img = Image.open('9.png')
img_new = img.resize((28, 28))

img_new = img_new.convert('L')
img_new = np.asarray(img_new)

img_new = img_new / 255.0

x = np.expand_dims(img_new, axis=0)
res = model.predict(x)
print(res)
print(f"Распознанная цифра: {np.argmax(res)}")
plt.imshow(img_new, cmap=plt.cm.binary)
plt.show()
# Out:
# [[4.2996970e-10 1.0113213e-05 2.2931501e-06 4.0742632e-02 3.3900051e-04
#   3.0565567e-05 6.6768612e-14 1.3359120e-05 5.0435399e-05 9.5881158e-01]]
# Распознанная цифра: 9
