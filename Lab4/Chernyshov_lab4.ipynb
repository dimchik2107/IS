# %% [markdown]
# # Лабораторная работа № 4
#
# Распознавание рукописных символов
#
# Выполнил:
#     Студент группы БФИ1901
#     Чернышов Дмитрий
#
# Задачи:
#
#    1. Ознакомиться с представлением графических данных
#    2. Ознакомиться с простейшим способом передачи графических данных нейронной сети
#    3. Создать модель
#    4. Настроить параметры обучения
#    5. Написать функцию, позволяющая загружать изображение пользователи и классифицировать его

# %% [markdown]
# # Цель работы:
# Реализовать классификацию черно-белых изображений рукописных цифр (28x28) по 10
# категориям (от 0 до 9). Набор данных содержит 60,000 изображений для обучения и 10,000 изображений для
# тестирования.

# %%
import tensorflow as tf
mnist = tf.keras.datasets.mnist
(train_images, train_labels),(test_images, test_labels) = mnist.load_data()

import matplotlib.pyplot as plt
plt.imshow(train_images[0],cmap=plt.cm.binary)
plt.show()
print(train_labels[0])

train_images = train_images / 255.0
test_images = test_images / 255.0

from tensorflow.keras.utils import to_categorical
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

from tensorflow.keras.layers import Dense, Activation, Flatten
from tensorflow.keras.models import Sequential
model = Sequential()
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(train_images, train_labels, epochs=5, batch_size=128)

test_loss, test_acc = model.evaluate(test_images, test_labels)
print('test_acc:', test_acc)
print('test_loss:', test_loss)
# Out:
# 5
# Epoch 1/5
# 469/469 [==============================] - 3s 4ms/step - loss: 0.3107 - accuracy: 0.9125
# Epoch 2/5
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1352 - accuracy: 0.9615
# Epoch 3/5
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0925 - accuracy: 0.9728
# Epoch 4/5
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0680 - accuracy: 0.9802
# Epoch 5/5
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0530 - accuracy: 0.9845
# 313/313 [==============================] - 2s 4ms/step - loss: 0.0779 - accuracy: 0.9757
# test_acc: 0.9757000207901001
# test_loss: 0.07793772220611572

# %%
import tensorflow as tf
mnist = tf.keras.datasets.mnist
(train_images, train_labels),(test_images, test_labels) = mnist.load_data()

import matplotlib.pyplot as plt
plt.imshow(train_images[0],cmap=plt.cm.binary)
plt.show()
print(train_labels[0])

train_images = train_images / 255.0
test_images = test_images / 255.0

from tensorflow.keras.utils import to_categorical
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

from tensorflow.keras.layers import Dense, Activation, Flatten
from tensorflow.keras.models import Sequential
model = Sequential()
model.add(Flatten())
model.add(Dense(30, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(train_images, train_labels, epochs=5, batch_size=128)

test_loss, test_acc = model.evaluate(test_images, test_labels)
print('test_acc:', test_acc)
print('test_loss:', test_loss)
# Out:
# 5
# Epoch 1/5
# 469/469 [==============================] - 3s 3ms/step - loss: 0.4850 - accuracy: 0.8708
# Epoch 2/5
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2485 - accuracy: 0.9301
# Epoch 3/5
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2036 - accuracy: 0.9425
# Epoch 4/5
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1755 - accuracy: 0.9508
# Epoch 5/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.1562 - accuracy: 0.9565
# 313/313 [==============================] - 2s 3ms/step - loss: 0.1561 - accuracy: 0.9557
# test_acc: 0.9556999802589417
# test_loss: 0.1560666263103485

# %%
import tensorflow as tf
mnist = tf.keras.datasets.mnist
(train_images, train_labels),(test_images, test_labels) = mnist.load_data()

import matplotlib.pyplot as plt
plt.imshow(train_images[0],cmap=plt.cm.binary)
plt.show()
print(train_labels[0])

train_images = train_images / 255.0
test_images = test_images / 255.0

from tensorflow.keras.utils import to_categorical
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

from tensorflow.keras.layers import Dense, Activation, Flatten
from tensorflow.keras.models import Sequential
model = Sequential()
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='SGD',loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(train_images, train_labels, epochs=5, batch_size=128)

test_loss, test_acc = model.evaluate(test_images, test_labels)
print('test_acc:', test_acc)
print('test_loss:', test_loss)
# Out:
# 5
# Epoch 1/5
# 469/469 [==============================] - 4s 4ms/step - loss: 1.2122 - accuracy: 0.6995
# Epoch 2/5
# 469/469 [==============================] - 2s 5ms/step - loss: 0.4793 - accuracy: 0.8752
# Epoch 3/5
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3755 - accuracy: 0.8965
# Epoch 4/5
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3308 - accuracy: 0.9074
# Epoch 5/5
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3032 - accuracy: 0.9141
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2772 - accuracy: 0.9221
# test_acc: 0.9221000075340271
# test_loss: 0.2772075831890106

# %%
import tensorflow as tf
mnist = tf.keras.datasets.mnist
(train_images, train_labels),(test_images, test_labels) = mnist.load_data()

import matplotlib.pyplot as plt
plt.imshow(train_images[0],cmap=plt.cm.binary)
plt.show()
print(train_labels[0])

train_images = train_images / 255.0
test_images = test_images / 255.0

from tensorflow.keras.utils import to_categorical
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

from tensorflow.keras.layers import Dense, Activation, Flatten
from tensorflow.keras.models import Sequential
model = Sequential()
model.add(Flatten())
model.add(Dense(30, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='RMSprop',loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(train_images, train_labels, epochs=5, batch_size=128)

test_loss, test_acc = model.evaluate(test_images, test_labels)
print('test_acc:', test_acc)
print('test_loss:', test_loss)
# Out:
# 5
# Epoch 1/5
# 469/469 [==============================] - 3s 3ms/step - loss: 0.4827 - accuracy: 0.8725
# Epoch 2/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.2494 - accuracy: 0.9293
# Epoch 3/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.2072 - accuracy: 0.9413
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1799 - accuracy: 0.9485
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1602 - accuracy: 0.9545
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1602 - accuracy: 0.9525
# test_acc: 0.9524999856948853
# test_loss: 0.16018423438072205

# %%
import tensorflow as tf
mnist = tf.keras.datasets.mnist
(train_images, train_labels),(test_images, test_labels) = mnist.load_data()

import matplotlib.pyplot as plt
plt.imshow(train_images[0],cmap=plt.cm.binary)
plt.show()
print(train_labels[0])

train_images = train_images / 255.0
test_images = test_images / 255.0

from tensorflow.keras.utils import to_categorical
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

from tensorflow.keras.layers import Dense, Activation, Flatten
from tensorflow.keras.models import Sequential
model = Sequential()
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(10, activation='softmax'))

x = tf.keras.optimizers.Adam(learning_rate=0.005)
model.compile(optimizer=x,loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(train_images, train_labels, epochs=5, batch_size=128)

test_loss, test_acc = model.evaluate(test_images, test_labels)
print('test_acc:', test_acc)
print('test_loss:', test_loss)
# Out:
# 5
# Epoch 1/5
# 469/469 [==============================] - 4s 5ms/step - loss: 0.2027 - accuracy: 0.9390
# Epoch 2/5
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0871 - accuracy: 0.9736
# Epoch 3/5
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0627 - accuracy: 0.9802
# Epoch 4/5
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0469 - accuracy: 0.9848
# Epoch 5/5
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0420 - accuracy: 0.9858
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0940 - accuracy: 0.9757
# test_acc: 0.9757000207901001
# test_loss: 0.09397093951702118

# %%
import tensorflow as tf
mnist = tf.keras.datasets.mnist
(train_images, train_labels),(test_images, test_labels) = mnist.load_data()

import matplotlib.pyplot as plt
plt.imshow(train_images[0],cmap=plt.cm.binary)
plt.show()
print(train_labels[0])

train_images = train_images / 255.0
test_images = test_images / 255.0

from tensorflow.keras.utils import to_categorical
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

from tensorflow.keras.layers import Dense, Activation, Flatten
from tensorflow.keras.models import Sequential
model = Sequential()
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(train_images, train_labels, epochs=5, batch_size=128)

test_loss, test_acc = model.evaluate(test_images, test_labels)
print('test_acc:', test_acc)
print('test_loss:', test_loss)
# Out:
# 5
# Epoch 1/5
# 469/469 [==============================] - 4s 5ms/step - loss: 0.3091 - accuracy: 0.9126
# Epoch 2/5
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1344 - accuracy: 0.9615
# Epoch 3/5
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0907 - accuracy: 0.9736
# Epoch 4/5
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0675 - accuracy: 0.9802
# Epoch 5/5
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0519 - accuracy: 0.9849
# 313/313 [==============================] - 2s 3ms/step - loss: 0.0806 - accuracy: 0.9751
# test_acc: 0.9750999808311462
# test_loss: 0.08062031865119934

# %%
import numpy as np
from PIL import Image
import tensorflow as tf
img = Image.open('33.png')
img_new = img.resize((28, 28), Image.ANTIALIAS)

img_new = img_new.convert('L')
img_new = np.asarray(img_new)

img_new = img_new / 255.0

x = np.expand_dims(img_new, axis=0)
res = model.predict(x)
print(res)
print(f"Распознанная цифра: {np.argmax(res)}")
plt.imshow(img_new, cmap=plt.cm.binary)
plt.show()
# Out:
# [[1.4429590e-02 5.0723165e-01 2.9719125e-02 4.8544953e-04 1.2642601e-02
#   7.5724251e-03 3.9229479e-01 1.5707572e-03 3.3974819e-02 7.8683865e-05]]
# Распознанная цифра: 1
